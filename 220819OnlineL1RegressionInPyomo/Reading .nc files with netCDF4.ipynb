# %% [markdown]
# **Streaming NWM data - https://console.cloud.google.com/storage/browser/national-water-model </br>
# *Read NetCDF Data with Python -  https://towardsdatascience.com/read-netcdf-data-with-python-901f7ff61648 </br>
# *Primary Climate Variables: Maximum temperature, minimum temperature, precipitation accumulation, downward surface shortwave radiation, wind-velocity, humidity (maximum and minimum relative humidity and specific humidity) - https://www.climatologylab.org/gridmet.html </br>
# *Reading data from the web into Python - https://towardsdatascience.com/an-efficient-way-to-read-data-from-the-web-directly-into-python-a526a0b4f4cb </br>
# *Content descriptions - https://water.noaa.gov/about/output_file_contents </br>
# *Analysis descriptions - https://water.noaa.gov/about/nwm </br>

# %%
import netCDF4 as nc
import pandas as pd
import numpy as np

# %%
#Read a.nc file that is in the same folder as this code (i.e. .ipynb file)
fn1 = 'nwm.20220818_analysis_assim_nwm.t00z.analysis_assim.channel_rt.tm00.conus.nc'

#Read the netcdf data set in the path fn
ds1 = nc.Dataset(fn1)


#Call 'streamflow' and 'velocity' columns in ds
streamflow1 = ds1['streamflow'][:]  # get data for variable
streamVelocity1 = ds1['velocity'][:]  # get data for variable


#Print the first and last 10 elements

    
print('first 10 of streamflow 1:', ds1['streamflow'][:10])
print('last 10 of streamflow 1:', ds1['streamflow'][len(ds1['streamflow'])-10:])
print('--')
#print(streamVelocity)
# Out:
# first 10 of streamflow 1: [0.04 0.01 0.01 0.06 0.08 0.   0.01 0.   0.01 0.04]
# last 10 of streamflow 1: [0.   0.05 0.   0.   0.   0.   0.   0.   0.   0.  ]
# --

# %%
#Apply query on .nc file to collect dense data points in a list
parameterList=['streamflow','nudge','velocity','qSfcLatRunoff','qBucket','qBtmVertRunoff']
lenData=len(ds1['streamflow'])
dataSet=[]
counter=0

for i in range(int(lenData)):
    ifCondition=True
    for parameter in parameterList: 
        if ds1[parameter][i] == 0 or ds1[parameter][i]== 'masked' or ds1[parameter][i]== None or ds1[parameter][i]== '--':  
            ifCondition=False
    if ifCondition==True:
        dataSet.append([])
        for j in range(len(parameterList)):
            dataSet[counter].append(ds1[parameterList[j]][i])
        dataSet[counter].append(i)
        if counter%100==0:
            print(f'Data point {i} appended, total number of points appended is: {counter}.')
        counter+=1
    if i%1000==0:
        print(f'{i}th data point has just been processed.')
#df = pd.DataFrame(dataSet)
#writer = pd.ExcelWriter('nwm.20220818_analysis_assim_nwm.t00z.analysis_assim.channel_rt.tm00.conus.RegressionData.xlsx',\
#                        engine='xlsxwriter')
#df.to_excel(writer, sheet_name='Data', index=False)
#writer.save()
# Out:
# Data point 0 appended, total number of points appended is: 0.
# 0th data point has just been processed.
# Data point 224 appended, total number of points appended is: 100.
# Data point 372 appended, total number of points appended is: 200.
# Data point 506 appended, total number of points appended is: 300.
# Data point 623 appended, total number of points appended is: 400.
# Data point 753 appended, total number of points appended is: 500.
# Data point 873 appended, total number of points appended is: 600.
# 1000th data point has just been processed.
# Data point 1018 appended, total number of points appended is: 700.
# Data point 1251 appended, total number of points appended is: 800.
# Data point 1446 appended, total number of points appended is: 900.
# Data point 1644 appended, total number of points appended is: 1000.
# Data point 1789 appended, total number of points appended is: 1100.
# Data point 1953 appended, total number of points appended is: 1200.
# 2000th data point has just been processed.
# Data point 2085 appended, total number of points appended is: 1300.
# Data point 2213 appended, total number of points appended is: 1400.
# Data point 2334 appended, total number of points appended is: 1500.
# Data point 2454 appended, total number of points appended is: 1600.
# Data point 2586 appended, total number of points appended is: 1700.
# Data point 2789 appended, total number of points appended is: 1800.
# 3000th data point has just been processed.
# Data point 3051 appended, total number of points appended is: 1900.
# Data point 3499 appended, total number of points appended is: 2000.
# Data point 3974 appended, total number of points appended is: 2100.
# 4000th data point has just been processed.
# Data point 4124 appended, total number of points appended is: 2200.
# Data point 4279 appended, total number of points appended is: 2300.
# Data point 4497 appended, total number of points appended is: 2400.
# Data point 4717 appended, total number of points appended is: 2500.
# Data point 4886 appended, total number of points appended is: 2600.
# 5000th data point has just been processed.
# Data point 5522 appended, total number of points appended is: 2700.
# Data point 5745 appended, total number of points appended is: 2800.
# 6000th data point has just been processed.
# Data point 6554 appended, total number of points appended is: 2900.
# 7000th data point has just been processed.
# Data point 7002 appended, total number of points appended is: 3000.
# Data point 7351 appended, total number of points appended is: 3100.
# Data point 7608 appended, total number of points appended is: 3200.
# 8000th data point has just been processed.
# Data point 8040 appended, total number of points appended is: 3300.
# Data point 8387 appended, total number of points appended is: 3400.
# Data point 8762 appended, total number of points appended is: 3500.
# 9000th data point has just been processed.
# Data point 9037 appended, total number of points appended is: 3600.
# Data point 9487 appended, total number of points appended is: 3700.
# Data point 9950 appended, total number of points appended is: 3800.
# 10000th data point has just been processed.
# Data point 10110 appended, total number of points appended is: 3900.
# Data point 10278 appended, total number of points appended is: 4000.
# Data point 10424 appended, total number of points appended is: 4100.
# Data point 10557 appended, total number of points appended is: 4200.
# Data point 10688 appended, total number of points appended is: 4300.
# Data point 10819 appended, total number of points appended is: 4400.
# Data point 10964 appended, total number of points appended is: 4500.
# 11000th data point has just been processed.
# Data point 11112 appended, total number of points appended is: 4600.
# Data point 11341 appended, total number of points appended is: 4700.
# Data point 11522 appended, total number of points appended is: 4800.
# Data point 11629 appended, total number of points appended is: 4900.
# 12000th data point has just been processed.
# Data point 12009 appended, total number of points appended is: 5000.
# Data point 12527 appended, total number of points appended is: 5100.
# 13000th data point has just been processed.
# Data point 13225 appended, total number of points appended is: 5200.
# 14000th data point has just been processed.
# Data point 14134 appended, total number of points appended is: 5300.
# Data point 14614 appended, total number of points appended is: 5400.
# Data point 14997 appended, total number of points appended is: 5500.
# 15000th data point has just been processed.
# Data point 15800 appended, total number of points appended is: 5600.
# 16000th data point has just been processed.
# Data point 16729 appended, total number of points appended is: 5700.
# 17000th data point has just been processed.
# Data point 17386 appended, total number of points appended is: 5800.
# Data point 17930 appended, total number of points appended is: 5900.
# 18000th data point has just been processed.
# Data point 18201 appended, total number of points appended is: 6000.
# Data point 18349 appended, total number of points appended is: 6100.
# Data point 18630 appended, total number of points appended is: 6200.
# Data point 18847 appended, total number of points appended is: 6300.
# 19000th data point has just been processed.
# Data point 19040 appended, total number of points appended is: 6400.
# Data point 19466 appended, total number of points appended is: 6500.
# 20000th data point has just been processed.
# Data point 20092 appended, total number of points appended is: 6600.
# Data point 20302 appended, total number of points appended is: 6700.
# Data point 20484 appended, total number of points appended is: 6800.
# Data point 20699 appended, total number of points appended is: 6900.
# Data point 20861 appended, total number of points appended is: 7000.
# 21000th data point has just been processed.
# Data point 21201 appended, total number of points appended is: 7100.
# Data point 21407 appended, total number of points appended is: 7200.
# Data point 21582 appended, total number of points appended is: 7300.
# Data point 21946 appended, total number of points appended is: 7400.
# 22000th data point has just been processed.
# Data point 22276 appended, total number of points appended is: 7500.
# Data point 22532 appended, total number of points appended is: 7600.
# Data point 22815 appended, total number of points appended is: 7700.
# 23000th data point has just been processed.
# Data point 23288 appended, total number of points appended is: 7800.
# Data point 23636 appended, total number of points appended is: 7900.
# Data point 23909 appended, total number of points appended is: 8000.
# 24000th data point has just been processed.
# Data point 24570 appended, total number of points appended is: 8100.
# 25000th data point has just been processed.
# Data point 25182 appended, total number of points appended is: 8200.
# Data point 25671 appended, total number of points appended is: 8300.
# Data point 25833 appended, total number of points appended is: 8400.
# Data point 25953 appended, total number of points appended is: 8500.
# 26000th data point has just been processed.
# Data point 26103 appended, total number of points appended is: 8600.
# Data point 26312 appended, total number of points appended is: 8700.
# Data point 26514 appended, total number of points appended is: 8800.
# Data point 26705 appended, total number of points appended is: 8900.
# Data point 26867 appended, total number of points appended is: 9000.
# 27000th data point has just been processed.
# Data point 27070 appended, total number of points appended is: 9100.
# Data point 27250 appended, total number of points appended is: 9200.
# Data point 27463 appended, total number of points appended is: 9300.
# Data point 27653 appended, total number of points appended is: 9400.
# Data point 27850 appended, total number of points appended is: 9500.
# 28000th data point has just been processed.
# Data point 28017 appended, total number of points appended is: 9600.
# Data point 28180 appended, total number of points appended is: 9700.
# Data point 28667 appended, total number of points appended is: 9800.
# 29000th data point has just been processed.
# Data point 29130 appended, total number of points appended is: 9900.
# Data point 29297 appended, total number of points appended is: 10000.
# Data point 29533 appended, total number of points appended is: 10100.
# Data point 29712 appended, total number of points appended is: 10200.
# Data point 29895 appended, total number of points appended is: 10300.
# 30000th data point has just been processed.
# Data point 30086 appended, total number of points appended is: 10400.
# Data point 30277 appended, total number of points appended is: 10500.
# Data point 30421 appended, total number of points appended is: 10600.
# Data point 30611 appended, total number of points appended is: 10700.
# Data point 30790 appended, total number of points appended is: 10800.
# Data point 30896 appended, total number of points appended is: 10900.
# 31000th data point has just been processed.
# Data point 31015 appended, total number of points appended is: 11000.
# Data point 31131 appended, total number of points appended is: 11100.
# Data point 31254 appended, total number of points appended is: 11200.
# Data point 31371 appended, total number of points appended is: 11300.
# Data point 31486 appended, total number of points appended is: 11400.
# Data point 31652 appended, total number of points appended is: 11500.
# Data point 31753 appended, total number of points appended is: 11600.
# Data point 31857 appended, total number of points appended is: 11700.
# Data point 31962 appended, total number of points appended is: 11800.
# 32000th data point has just been processed.
# Data point 32068 appended, total number of points appended is: 11900.
# Data point 32189 appended, total number of points appended is: 12000.
# Data point 32298 appended, total number of points appended is: 12100.
# Data point 32403 appended, total number of points appended is: 12200.
# Data point 32528 appended, total number of points appended is: 12300.
# Data point 32780 appended, total number of points appended is: 12400.
# Data point 32985 appended, total number of points appended is: 12500.
# 33000th data point has just been processed.
# Data point 33143 appended, total number of points appended is: 12600.
# Data point 33250 appended, total number of points appended is: 12700.
# Data point 33359 appended, total number of points appended is: 12800.
# Data point 33490 appended, total number of points appended is: 12900.
# Data point 33611 appended, total number of points appended is: 13000.
# Data point 33727 appended, total number of points appended is: 13100.
# Data point 33851 appended, total number of points appended is: 13200.
# Data point 33991 appended, total number of points appended is: 13300.
# 34000th data point has just been processed.
# Data point 34177 appended, total number of points appended is: 13400.
# Data point 34345 appended, total number of points appended is: 13500.
# Data point 34513 appended, total number of points appended is: 13600.
# Data point 34796 appended, total number of points appended is: 13700.
# Data point 34960 appended, total number of points appended is: 13800.
# 35000th data point has just been processed.
# Data point 35256 appended, total number of points appended is: 13900.
# Data point 35458 appended, total number of points appended is: 14000.
# Data point 35585 appended, total number of points appended is: 14100.
# Data point 35701 appended, total number of points appended is: 14200.
# Data point 35811 appended, total number of points appended is: 14300.
# Data point 35915 appended, total number of points appended is: 14400.
# 36000th data point has just been processed.
# Data point 36039 appended, total number of points appended is: 14500.
# Data point 36281 appended, total number of points appended is: 14600.
# Data point 36694 appended, total number of points appended is: 14700.
# Data point 36835 appended, total number of points appended is: 14800.
# Data point 36984 appended, total number of points appended is: 14900.
# 37000th data point has just been processed.
# Data point 37153 appended, total number of points appended is: 15000.
# Data point 37309 appended, total number of points appended is: 15100.
# 38000th data point has just been processed.
# Data point 38332 appended, total number of points appended is: 15200.
# Data point 38801 appended, total number of points appended is: 15300.
# 39000th data point has just been processed.
# Data point 39231 appended, total number of points appended is: 15400.
# Data point 39371 appended, total number of points appended is: 15500.
# Data point 39528 appended, total number of points appended is: 15600.
# Data point 39688 appended, total number of points appended is: 15700.
# Data point 39822 appended, total number of points appended is: 15800.
# Data point 39951 appended, total number of points appended is: 15900.
# 40000th data point has just been processed.
# Data point 40098 appended, total number of points appended is: 16000.
# Data point 40317 appended, total number of points appended is: 16100.
# Data point 40631 appended, total number of points appended is: 16200.
# 41000th data point has just been processed.
# Data point 41340 appended, total number of points appended is: 16300.
# Data point 41629 appended, total number of points appended is: 16400.
# 42000th data point has just been processed.
# Data point 42087 appended, total number of points appended is: 16500.
# Data point 42538 appended, total number of points appended is: 16600.
# Data point 42980 appended, total number of points appended is: 16700.
# 43000th data point has just been processed.
# Data point 43538 appended, total number of points appended is: 16800.
# Data point 43946 appended, total number of points appended is: 16900.
# 44000th data point has just been processed.
# Data point 44348 appended, total number of points appended is: 17000.
# Data point 44479 appended, total number of points appended is: 17100.
# 45000th data point has just been processed.
# Data point 45394 appended, total number of points appended is: 17200.
# 46000th data point has just been processed.
# Data point 46060 appended, total number of points appended is: 17300.
# Data point 46770 appended, total number of points appended is: 17400.
# Data point 46930 appended, total number of points appended is: 17500.
# 47000th data point has just been processed.
# Data point 47317 appended, total number of points appended is: 17600.
# 48000th data point has just been processed.
# Data point 48062 appended, total number of points appended is: 17700.
# Data point 48732 appended, total number of points appended is: 17800.
# 49000th data point has just been processed.
# Data point 49722 appended, total number of points appended is: 17900.
# Data point 49964 appended, total number of points appended is: 18000.
# 50000th data point has just been processed.
# Data point 50119 appended, total number of points appended is: 18100.
# Data point 50328 appended, total number of points appended is: 18200.
# Data point 50654 appended, total number of points appended is: 18300.
# Data point 50852 appended, total number of points appended is: 18400.
# 51000th data point has just been processed.
# Data point 51078 appended, total number of points appended is: 18500.
# Data point 51558 appended, total number of points appended is: 18600.
# Data point 51863 appended, total number of points appended is: 18700.
# 52000th data point has just been processed.
# Data point 52019 appended, total number of points appended is: 18800.
# Data point 52460 appended, total number of points appended is: 18900.
# Data point 52834 appended, total number of points appended is: 19000.
# 53000th data point has just been processed.
# Data point 53699 appended, total number of points appended is: 19100.
# 54000th data point has just been processed.
# Data point 54222 appended, total number of points appended is: 19200.
# Data point 54473 appended, total number of points appended is: 19300.
# Data point 54596 appended, total number of points appended is: 19400.
# Data point 54816 appended, total number of points appended is: 19500.
# 55000th data point has just been processed.
# Data point 55128 appended, total number of points appended is: 19600.
# Data point 55340 appended, total number of points appended is: 19700.
# Data point 55484 appended, total number of points appended is: 19800.
# Data point 55745 appended, total number of points appended is: 19900.
# Data point 55971 appended, total number of points appended is: 20000.
# 56000th data point has just been processed.
# Data point 56104 appended, total number of points appended is: 20100.
# Data point 56289 appended, total number of points appended is: 20200.
# Data point 56541 appended, total number of points appended is: 20300.
# Data point 56663 appended, total number of points appended is: 20400.
# Data point 56787 appended, total number of points appended is: 20500.
# Data point 56915 appended, total number of points appended is: 20600.
# 57000th data point has just been processed.
# Data point 57030 appended, total number of points appended is: 20700.
# Data point 57605 appended, total number of points appended is: 20800.
# 58000th data point has just been processed.
# Data point 58377 appended, total number of points appended is: 20900.
# 59000th data point has just been processed.
# Data point 59122 appended, total number of points appended is: 21000.
# Data point 59875 appended, total number of points appended is: 21100.
# 60000th data point has just been processed.
# Data point 60197 appended, total number of points appended is: 21200.
# Data point 60310 appended, total number of points appended is: 21300.
# Data point 60414 appended, total number of points appended is: 21400.
# Data point 60662 appended, total number of points appended is: 21500.
# 61000th data point has just been processed.
# Data point 61880 appended, total number of points appended is: 21600.
# 62000th data point has just been processed.
# Data point 62248 appended, total number of points appended is: 21700.
# Data point 62497 appended, total number of points appended is: 21800.
# Data point 62689 appended, total number of points appended is: 21900.
# Data point 62844 appended, total number of points appended is: 22000.
# Data point 62995 appended, total number of points appended is: 22100.
# 63000th data point has just been processed.
# Data point 63129 appended, total number of points appended is: 22200.
# Data point 63276 appended, total number of points appended is: 22300.
# Data point 63399 appended, total number of points appended is: 22400.
# Data point 63515 appended, total number of points appended is: 22500.
# Data point 63624 appended, total number of points appended is: 22600.
# Data point 63762 appended, total number of points appended is: 22700.
# Data point 63881 appended, total number of points appended is: 22800.
# Data point 64000 appended, total number of points appended is: 22900.
# 64000th data point has just been processed.
# Data point 64110 appended, total number of points appended is: 23000.
# Data point 64362 appended, total number of points appended is: 23100.
# Data point 64716 appended, total number of points appended is: 23200.
# 65000th data point has just been processed.
# Data point 65222 appended, total number of points appended is: 23300.
# Data point 65660 appended, total number of points appended is: 23400.
# Data point 65795 appended, total number of points appended is: 23500.
# Data point 65942 appended, total number of points appended is: 23600.
# 66000th data point has just been processed.
# Data point 66096 appended, total number of points appended is: 23700.
# Data point 66231 appended, total number of points appended is: 23800.
# Data point 66559 appended, total number of points appended is: 23900.
# Data point 66850 appended, total number of points appended is: 24000.
# 67000th data point has just been processed.
# Data point 67042 appended, total number of points appended is: 24100.
# Data point 67331 appended, total number of points appended is: 24200.
# Data point 67575 appended, total number of points appended is: 24300.
# Data point 67971 appended, total number of points appended is: 24400.
# 68000th data point has just been processed.
# Data point 68261 appended, total number of points appended is: 24500.
# Data point 68527 appended, total number of points appended is: 24600.
# Data point 68755 appended, total number of points appended is: 24700.
# Data point 68882 appended, total number of points appended is: 24800.
# 69000th data point has just been processed.
# Data point 69001 appended, total number of points appended is: 24900.
# Data point 69217 appended, total number of points appended is: 25000.
# Data point 69357 appended, total number of points appended is: 25100.
# Data point 69509 appended, total number of points appended is: 25200.
# Data point 69701 appended, total number of points appended is: 25300.
# Data point 69900 appended, total number of points appended is: 25400.
# 70000th data point has just been processed.
# Data point 70141 appended, total number of points appended is: 25500.
# Data point 70253 appended, total number of points appended is: 25600.
# Data point 70373 appended, total number of points appended is: 25700.
# Data point 70508 appended, total number of points appended is: 25800.
# Data point 70629 appended, total number of points appended is: 25900.
# Data point 70736 appended, total number of points appended is: 26000.
# Data point 70867 appended, total number of points appended is: 26100.
# Data point 70977 appended, total number of points appended is: 26200.
# 71000th data point has just been processed.
# Data point 71081 appended, total number of points appended is: 26300.
# Data point 71202 appended, total number of points appended is: 26400.
# Data point 71354 appended, total number of points appended is: 26500.
# Data point 71546 appended, total number of points appended is: 26600.
# Data point 71712 appended, total number of points appended is: 26700.
# Data point 71862 appended, total number of points appended is: 26800.
# 72000th data point has just been processed.
# Data point 72028 appended, total number of points appended is: 26900.
# Data point 72176 appended, total number of points appended is: 27000.
# Data point 72301 appended, total number of points appended is: 27100.
# Data point 72446 appended, total number of points appended is: 27200.
# Data point 72623 appended, total number of points appended is: 27300.
# Data point 72797 appended, total number of points appended is: 27400.
# Data point 72926 appended, total number of points appended is: 27500.
# 73000th data point has just been processed.
# Data point 73046 appended, total number of points appended is: 27600.
# Data point 73209 appended, total number of points appended is: 27700.
# Data point 73362 appended, total number of points appended is: 27800.
# Data point 73523 appended, total number of points appended is: 27900.
# Data point 73679 appended, total number of points appended is: 28000.
# Data point 73913 appended, total number of points appended is: 28100.
# 74000th data point has just been processed.
# Data point 74315 appended, total number of points appended is: 28200.
# Data point 74539 appended, total number of points appended is: 28300.
# Data point 74788 appended, total number of points appended is: 28400.
# Data point 74991 appended, total number of points appended is: 28500.
# 75000th data point has just been processed.
# Data point 75118 appended, total number of points appended is: 28600.
# Data point 75263 appended, total number of points appended is: 28700.
# Data point 75424 appended, total number of points appended is: 28800.
# Data point 75557 appended, total number of points appended is: 28900.
# Data point 75698 appended, total number of points appended is: 29000.
# Data point 75841 appended, total number of points appended is: 29100.
# 76000th data point has just been processed.
# Data point 76005 appended, total number of points appended is: 29200.
# Data point 76146 appended, total number of points appended is: 29300.
# Data point 76568 appended, total number of points appended is: 29400.
# Data point 76673 appended, total number of points appended is: 29500.
# Data point 76845 appended, total number of points appended is: 29600.
# 77000th data point has just been processed.
# Data point 77032 appended, total number of points appended is: 29700.
# Data point 77247 appended, total number of points appended is: 29800.
# Data point 77408 appended, total number of points appended is: 29900.
# Data point 77544 appended, total number of points appended is: 30000.
# Data point 77675 appended, total number of points appended is: 30100.
# Data point 77841 appended, total number of points appended is: 30200.
# Data point 77968 appended, total number of points appended is: 30300.
# 78000th data point has just been processed.
# Data point 78070 appended, total number of points appended is: 30400.
# Data point 78254 appended, total number of points appended is: 30500.
# Data point 78372 appended, total number of points appended is: 30600.
# Data point 78484 appended, total number of points appended is: 30700.
# Data point 78585 appended, total number of points appended is: 30800.
# Data point 78688 appended, total number of points appended is: 30900.
# Data point 78832 appended, total number of points appended is: 31000.
# 79000th data point has just been processed.
# Data point 79001 appended, total number of points appended is: 31100.
# Data point 79119 appended, total number of points appended is: 31200.
# Data point 79228 appended, total number of points appended is: 31300.
# Data point 79342 appended, total number of points appended is: 31400.
# Data point 79448 appended, total number of points appended is: 31500.
# Data point 79563 appended, total number of points appended is: 31600.
# Data point 79670 appended, total number of points appended is: 31700.
# Data point 79782 appended, total number of points appended is: 31800.
# Data point 79882 appended, total number of points appended is: 31900.
# 80000th data point has just been processed.
# Data point 80050 appended, total number of points appended is: 32000.
# Data point 80173 appended, total number of points appended is: 32100.
# Data point 80309 appended, total number of points appended is: 32200.
# Data point 80443 appended, total number of points appended is: 32300.
# Data point 80867 appended, total number of points appended is: 32400.
# 81000th data point has just been processed.
# Data point 81021 appended, total number of points appended is: 32500.
# Data point 81332 appended, total number of points appended is: 32600.
# Data point 81648 appended, total number of points appended is: 32700.
# 82000th data point has just been processed.
# Data point 82243 appended, total number of points appended is: 32800.
# Data point 82724 appended, total number of points appended is: 32900.
# Data point 82886 appended, total number of points appended is: 33000.
# 83000th data point has just been processed.
# Data point 83038 appended, total number of points appended is: 33100.
# Data point 83326 appended, total number of points appended is: 33200.
# Data point 83876 appended, total number of points appended is: 33300.
# 84000th data point has just been processed.
# Data point 84748 appended, total number of points appended is: 33400.
# 85000th data point has just been processed.
# Data point 85123 appended, total number of points appended is: 33500.
# Data point 85861 appended, total number of points appended is: 33600.
# 86000th data point has just been processed.
# Data point 86258 appended, total number of points appended is: 33700.
# Data point 86899 appended, total number of points appended is: 33800.
# 87000th data point has just been processed.
# Data point 87708 appended, total number of points appended is: 33900.
# 88000th data point has just been processed.
# Data point 88280 appended, total number of points appended is: 34000.
# Data point 88888 appended, total number of points appended is: 34100.
# 89000th data point has just been processed.
# Data point 89157 appended, total number of points appended is: 34200.
# Data point 89382 appended, total number of points appended is: 34300.
# Data point 89542 appended, total number of points appended is: 34400.
# Data point 89738 appended, total number of points appended is: 34500.
# Data point 89875 appended, total number of points appended is: 34600.
# Data point 89997 appended, total number of points appended is: 34700.
# 90000th data point has just been processed.
# Data point 90151 appended, total number of points appended is: 34800.
# Data point 90283 appended, total number of points appended is: 34900.
# Data point 90552 appended, total number of points appended is: 35000.
# Data point 90714 appended, total number of points appended is: 35100.
# Data point 90843 appended, total number of points appended is: 35200.
# Data point 90976 appended, total number of points appended is: 35300.
# 91000th data point has just been processed.
# Data point 91215 appended, total number of points appended is: 35400.
# Data point 91718 appended, total number of points appended is: 35500.
# Data point 91928 appended, total number of points appended is: 35600.
# 92000th data point has just been processed.
# Data point 92120 appended, total number of points appended is: 35700.
# Data point 92290 appended, total number of points appended is: 35800.
# Data point 92467 appended, total number of points appended is: 35900.
# Data point 92602 appended, total number of points appended is: 36000.
# Data point 92830 appended, total number of points appended is: 36100.
# 93000th data point has just been processed.
# Data point 93014 appended, total number of points appended is: 36200.
# Data point 93210 appended, total number of points appended is: 36300.
# Data point 93370 appended, total number of points appended is: 36400.
# Data point 93543 appended, total number of points appended is: 36500.
# Data point 93721 appended, total number of points appended is: 36600.
# Data point 93890 appended, total number of points appended is: 36700.
# 94000th data point has just been processed.
# Data point 94249 appended, total number of points appended is: 36800.
# Data point 94437 appended, total number of points appended is: 36900.
# Data point 94600 appended, total number of points appended is: 37000.
# Data point 94794 appended, total number of points appended is: 37100.
# Data point 94944 appended, total number of points appended is: 37200.
# 95000th data point has just been processed.
# Data point 95121 appended, total number of points appended is: 37300.
# Data point 95293 appended, total number of points appended is: 37400.
# Data point 95470 appended, total number of points appended is: 37500.
# Data point 95630 appended, total number of points appended is: 37600.
# 96000th data point has just been processed.
# Data point 96021 appended, total number of points appended is: 37700.
# Data point 96275 appended, total number of points appended is: 37800.
# Data point 96821 appended, total number of points appended is: 37900.
# Data point 96936 appended, total number of points appended is: 38000.
# 97000th data point has just been processed.
# Data point 97150 appended, total number of points appended is: 38100.
# Data point 97308 appended, total number of points appended is: 38200.
# Data point 97448 appended, total number of points appended is: 38300.
# Data point 97578 appended, total number of points appended is: 38400.
# Data point 97698 appended, total number of points appended is: 38500.
# Data point 97833 appended, total number of points appended is: 38600.
# Data point 97950 appended, total number of points appended is: 38700.
# 98000th data point has just been processed.
# Data point 98064 appended, total number of points appended is: 38800.
# Data point 98195 appended, total number of points appended is: 38900.
# Data point 98325 appended, total number of points appended is: 39000.
# Data point 98439 appended, total number of points appended is: 39100.
# Data point 98564 appended, total number of points appended is: 39200.
# Data point 98699 appended, total number of points appended is: 39300.
# Data point 98843 appended, total number of points appended is: 39400.
# Data point 98982 appended, total number of points appended is: 39500.
# 99000th data point has just been processed.
# Data point 99165 appended, total number of points appended is: 39600.
# Data point 99530 appended, total number of points appended is: 39700.
# Data point 99770 appended, total number of points appended is: 39800.
# Data point 99966 appended, total number of points appended is: 39900.
# 100000th data point has just been processed.
# Data point 100612 appended, total number of points appended is: 40000.
# Data point 100838 appended, total number of points appended is: 40100.
# 101000th data point has just been processed.
# Data point 101072 appended, total number of points appended is: 40200.
# Data point 101409 appended, total number of points appended is: 40300.
# Data point 101626 appended, total number of points appended is: 40400.
# Data point 101799 appended, total number of points appended is: 40500.
# 102000th data point has just been processed.
# Data point 102057 appended, total number of points appended is: 40600.
# Data point 102349 appended, total number of points appended is: 40700.
# Data point 102621 appended, total number of points appended is: 40800.
# Data point 102831 appended, total number of points appended is: 40900.
# 103000th data point has just been processed.
# Data point 103088 appended, total number of points appended is: 41000.
# Data point 103311 appended, total number of points appended is: 41100.
# Data point 103530 appended, total number of points appended is: 41200.
# Data point 103698 appended, total number of points appended is: 41300.
# Data point 103887 appended, total number of points appended is: 41400.
# 104000th data point has just been processed.
# Data point 104467 appended, total number of points appended is: 41500.
# Data point 104878 appended, total number of points appended is: 41600.
# 105000th data point has just been processed.
# Data point 105120 appended, total number of points appended is: 41700.
# 106000th data point has just been processed.
# Data point 106427 appended, total number of points appended is: 41800.
# Data point 106946 appended, total number of points appended is: 41900.
# 107000th data point has just been processed.
# Data point 107670 appended, total number of points appended is: 42000.
# 108000th data point has just been processed.
# Data point 108366 appended, total number of points appended is: 42100.
# Data point 108635 appended, total number of points appended is: 42200.
# Data point 108933 appended, total number of points appended is: 42300.
# 109000th data point has just been processed.
# 110000th data point has just been processed.
# Data point 110190 appended, total number of points appended is: 42400.
# Data point 110568 appended, total number of points appended is: 42500.
# Data point 110906 appended, total number of points appended is: 42600.
# 111000th data point has just been processed.
# Data point 111056 appended, total number of points appended is: 42700.
# Data point 111239 appended, total number of points appended is: 42800.
# Data point 111400 appended, total number of points appended is: 42900.
# Data point 111542 appended, total number of points appended is: 43000.
# Data point 111766 appended, total number of points appended is: 43100.
# 112000th data point has just been processed.
# Data point 112183 appended, total number of points appended is: 43200.
# Data point 112472 appended, total number of points appended is: 43300.
# Data point 112731 appended, total number of points appended is: 43400.
# Data point 112872 appended, total number of points appended is: 43500.
# 113000th data point has just been processed.
# Data point 113015 appended, total number of points appended is: 43600.
# Data point 113164 appended, total number of points appended is: 43700.
# Data point 113286 appended, total number of points appended is: 43800.
# Data point 113397 appended, total number of points appended is: 43900.
# Data point 113676 appended, total number of points appended is: 44000.
# Data point 113994 appended, total number of points appended is: 44100.
# 114000th data point has just been processed.
# Data point 114374 appended, total number of points appended is: 44200.
# Data point 114834 appended, total number of points appended is: 44300.
# 115000th data point has just been processed.
# Data point 115201 appended, total number of points appended is: 44400.
# Data point 115442 appended, total number of points appended is: 44500.
# 116000th data point has just been processed.
# Data point 116148 appended, total number of points appended is: 44600.
# Data point 116338 appended, total number of points appended is: 44700.
# Data point 116726 appended, total number of points appended is: 44800.
# 117000th data point has just been processed.
# Data point 117182 appended, total number of points appended is: 44900.
# Data point 117467 appended, total number of points appended is: 45000.
# Data point 117809 appended, total number of points appended is: 45100.
# Data point 117975 appended, total number of points appended is: 45200.
# 118000th data point has just been processed.
# Data point 118217 appended, total number of points appended is: 45300.
# Data point 118412 appended, total number of points appended is: 45400.
# Data point 118558 appended, total number of points appended is: 45500.
# Data point 118809 appended, total number of points appended is: 45600.
# 119000th data point has just been processed.
# Data point 119095 appended, total number of points appended is: 45700.
# Data point 119292 appended, total number of points appended is: 45800.
# Data point 119477 appended, total number of points appended is: 45900.
# Data point 119627 appended, total number of points appended is: 46000.
# Data point 119768 appended, total number of points appended is: 46100.
# Data point 119914 appended, total number of points appended is: 46200.
# 120000th data point has just been processed.
# Data point 120032 appended, total number of points appended is: 46300.
# Data point 120204 appended, total number of points appended is: 46400.
# Data point 120604 appended, total number of points appended is: 46500.
# Data point 120768 appended, total number of points appended is: 46600.
# Data point 120971 appended, total number of points appended is: 46700.
# 121000th data point has just been processed.
# Data point 121195 appended, total number of points appended is: 46800.
# Data point 121633 appended, total number of points appended is: 46900.
# Data point 121780 appended, total number of points appended is: 47000.
# Data point 121931 appended, total number of points appended is: 47100.
# 122000th data point has just been processed.
# Data point 122159 appended, total number of points appended is: 47200.
# Data point 122305 appended, total number of points appended is: 47300.
# Data point 122447 appended, total number of points appended is: 47400.
# Data point 122573 appended, total number of points appended is: 47500.
# Data point 122763 appended, total number of points appended is: 47600.
# 123000th data point has just been processed.
# Data point 123255 appended, total number of points appended is: 47700.
# Data point 123566 appended, total number of points appended is: 47800.
# Data point 123858 appended, total number of points appended is: 47900.
# 124000th data point has just been processed.
# Data point 124116 appended, total number of points appended is: 48000.
# Data point 124297 appended, total number of points appended is: 48100.
# Data point 124503 appended, total number of points appended is: 48200.
# Data point 124695 appended, total number of points appended is: 48300.
# Data point 124925 appended, total number of points appended is: 48400.
# 125000th data point has just been processed.
# Data point 125295 appended, total number of points appended is: 48500.
# 126000th data point has just been processed.
# 127000th data point has just been processed.
# Data point 127988 appended, total number of points appended is: 48600.
# 128000th data point has just been processed.
# Data point 128731 appended, total number of points appended is: 48700.
# 129000th data point has just been processed.
# 130000th data point has just been processed.
# Data point 130568 appended, total number of points appended is: 48800.
# 131000th data point has just been processed.
# Data point 131539 appended, total number of points appended is: 48900.
# 132000th data point has just been processed.
# Data point 132392 appended, total number of points appended is: 49000.
# Data point 132680 appended, total number of points appended is: 49100.
# 133000th data point has just been processed.
# Data point 133022 appended, total number of points appended is: 49200.
# Data point 133155 appended, total number of points appended is: 49300.
# Data point 133266 appended, total number of points appended is: 49400.
# Data point 133379 appended, total number of points appended is: 49500.
# Data point 133480 appended, total number of points appended is: 49600.
# Data point 133749 appended, total number of points appended is: 49700.
# 134000th data point has just been processed.
# Data point 134118 appended, total number of points appended is: 49800.
# Data point 134481 appended, total number of points appended is: 49900.
# Data point 134859 appended, total number of points appended is: 50000.
# 135000th data point has just been processed.
# Data point 135010 appended, total number of points appended is: 50100.
# Data point 135295 appended, total number of points appended is: 50200.
# Data point 135692 appended, total number of points appended is: 50300.
# 136000th data point has just been processed.
# Data point 136020 appended, total number of points appended is: 50400.
# Data point 136142 appended, total number of points appended is: 50500.
# Data point 136317 appended, total number of points appended is: 50600.
# Data point 136482 appended, total number of points appended is: 50700.
# Data point 136702 appended, total number of points appended is: 50800.
# 137000th data point has just been processed.
# Data point 137071 appended, total number of points appended is: 50900.
# Data point 137502 appended, total number of points appended is: 51000.
# Data point 137817 appended, total number of points appended is: 51100.
# 138000th data point has just been processed.
# Data point 138257 appended, total number of points appended is: 51200.
# Data point 138637 appended, total number of points appended is: 51300.

# %%
#Collect numerical data in .nc file to lists
parameterList=['streamflow','nudge','velocity','qSfcLatRunoff','qBucket','qBtmVertRunoff']
lenData=len(ds1['streamflow'])
dataSet=[]
counter=0

for i in range(int(lenData)):
    dataSet.append([])
    for j in range(len(parameterList)):
        dataSet[i].append(ds1[parameterList[j]][i])
    if i%1000==0:
        print(f'{i}th data point has just been processed.')
        
df = pd.DataFrame(dataSet)
writer = pd.ExcelWriter('1of3nwm.20220818_analysis_assim_nwm.t00z.analysis_assim.channel_rt.tm00.conus.RegressionData.xlsx',\
                        engine='xlsxwriter')
df.to_excel(writer, sheet_name='Data', index=False)
writer.save()
# Out:
# 0th data point has just been processed.
# 1000th data point has just been processed.
# 2000th data point has just been processed.
# 3000th data point has just been processed.
# 4000th data point has just been processed.
# 5000th data point has just been processed.
# 6000th data point has just been processed.
# 7000th data point has just been processed.
# 8000th data point has just been processed.
# 9000th data point has just been processed.
# 10000th data point has just been processed.
# 11000th data point has just been processed.
# 12000th data point has just been processed.
# 13000th data point has just been processed.
# 14000th data point has just been processed.
# 15000th data point has just been processed.
# 16000th data point has just been processed.
# 17000th data point has just been processed.
# 18000th data point has just been processed.
# 19000th data point has just been processed.
# 20000th data point has just been processed.
# 21000th data point has just been processed.
# 22000th data point has just been processed.
# 23000th data point has just been processed.
# 24000th data point has just been processed.
# 25000th data point has just been processed.
# 26000th data point has just been processed.
# 27000th data point has just been processed.
# 28000th data point has just been processed.
# 29000th data point has just been processed.
# 30000th data point has just been processed.
# 31000th data point has just been processed.
# 32000th data point has just been processed.
# 33000th data point has just been processed.
# 34000th data point has just been processed.
# 35000th data point has just been processed.
# 36000th data point has just been processed.
# 37000th data point has just been processed.
# 38000th data point has just been processed.
# 39000th data point has just been processed.
# 40000th data point has just been processed.
# 41000th data point has just been processed.
# 42000th data point has just been processed.
# 43000th data point has just been processed.
# 44000th data point has just been processed.
# 45000th data point has just been processed.
# 46000th data point has just been processed.
# 47000th data point has just been processed.
# 48000th data point has just been processed.
# 49000th data point has just been processed.
# 50000th data point has just been processed.
# 51000th data point has just been processed.
# 52000th data point has just been processed.
# 53000th data point has just been processed.
# 54000th data point has just been processed.
# 55000th data point has just been processed.
# 56000th data point has just been processed.
# 57000th data point has just been processed.
# 58000th data point has just been processed.
# 59000th data point has just been processed.
# 60000th data point has just been processed.
# 61000th data point has just been processed.
# 62000th data point has just been processed.
# 63000th data point has just been processed.
# 64000th data point has just been processed.
# 65000th data point has just been processed.
# 66000th data point has just been processed.
# 67000th data point has just been processed.
# 68000th data point has just been processed.
# 69000th data point has just been processed.
# 70000th data point has just been processed.
# 71000th data point has just been processed.
# 72000th data point has just been processed.
# 73000th data point has just been processed.
# 74000th data point has just been processed.
# 75000th data point has just been processed.
# 76000th data point has just been processed.
# 77000th data point has just been processed.
# 78000th data point has just been processed.
# 79000th data point has just been processed.
# 80000th data point has just been processed.
# 81000th data point has just been processed.
# 82000th data point has just been processed.
# 83000th data point has just been processed.
# 84000th data point has just been processed.
# 85000th data point has just been processed.
# 86000th data point has just been processed.
# 87000th data point has just been processed.
# 88000th data point has just been processed.
# 89000th data point has just been processed.
# 90000th data point has just been processed.
# 91000th data point has just been processed.
# 92000th data point has just been processed.
# 93000th data point has just been processed.
# 94000th data point has just been processed.
# 95000th data point has just been processed.
# 96000th data point has just been processed.
# 97000th data point has just been processed.
# 98000th data point has just been processed.
# 99000th data point has just been processed.
# 100000th data point has just been processed.
# 101000th data point has just been processed.
# 102000th data point has just been processed.
# 103000th data point has just been processed.
# 104000th data point has just been processed.
# 105000th data point has just been processed.
# 106000th data point has just been processed.
# 107000th data point has just been processed.
# 108000th data point has just been processed.
# 109000th data point has just been processed.
# 110000th data point has just been processed.
# 111000th data point has just been processed.
# 112000th data point has just been processed.
# 113000th data point has just been processed.
# 114000th data point has just been processed.
# 115000th data point has just been processed.
# 116000th data point has just been processed.
# 117000th data point has just been processed.
# 118000th data point has just been processed.
# 119000th data point has just been processed.
# 120000th data point has just been processed.
# 121000th data point has just been processed.
# 122000th data point has just been processed.
# 123000th data point has just been processed.
# 124000th data point has just been processed.
# 125000th data point has just been processed.
# 126000th data point has just been processed.
# 127000th data point has just been processed.
# 128000th data point has just been processed.
# 129000th data point has just been processed.
# 130000th data point has just been processed.
# 131000th data point has just been processed.
# 132000th data point has just been processed.
# 133000th data point has just been processed.
# 134000th data point has just been processed.
# 135000th data point has just been processed.
# 136000th data point has just been processed.
# 137000th data point has just been processed.
# 138000th data point has just been processed.
# 139000th data point has just been processed.
# 140000th data point has just been processed.
# 141000th data point has just been processed.
# 142000th data point has just been processed.
# 143000th data point has just been processed.
# 144000th data point has just been processed.
# 145000th data point has just been processed.
# 146000th data point has just been processed.
# 147000th data point has just been processed.
# 148000th data point has just been processed.
# 149000th data point has just been processed.
# 150000th data point has just been processed.
# 151000th data point has just been processed.
# 152000th data point has just been processed.
# 153000th data point has just been processed.
# 154000th data point has just been processed.
# 155000th data point has just been processed.
# 156000th data point has just been processed.
# 157000th data point has just been processed.
# 158000th data point has just been processed.
# 159000th data point has just been processed.
# 160000th data point has just been processed.
# 161000th data point has just been processed.
# 162000th data point has just been processed.
# 163000th data point has just been processed.
# 164000th data point has just been processed.
# 165000th data point has just been processed.
# 166000th data point has just been processed.
# 167000th data point has just been processed.
# 168000th data point has just been processed.
# 169000th data point has just been processed.
# 170000th data point has just been processed.
# 171000th data point has just been processed.
# 172000th data point has just been processed.
# 173000th data point has just been processed.
# 174000th data point has just been processed.
# 175000th data point has just been processed.
# 176000th data point has just been processed.
# 177000th data point has just been processed.
# 178000th data point has just been processed.
# 179000th data point has just been processed.
# 180000th data point has just been processed.
# 181000th data point has just been processed.
# 182000th data point has just been processed.
# 183000th data point has just been processed.
# 184000th data point has just been processed.
# 185000th data point has just been processed.
# 186000th data point has just been processed.
# 187000th data point has just been processed.
# 188000th data point has just been processed.
# 189000th data point has just been processed.
# 190000th data point has just been processed.
# 191000th data point has just been processed.
# 192000th data point has just been processed.
# 193000th data point has just been processed.
# 194000th data point has just been processed.
# 195000th data point has just been processed.
# 196000th data point has just been processed.
# 197000th data point has just been processed.
# 198000th data point has just been processed.
# 199000th data point has just been processed.
# 200000th data point has just been processed.
# 201000th data point has just been processed.
# 202000th data point has just been processed.
# 203000th data point has just been processed.
# 204000th data point has just been processed.
# 205000th data point has just been processed.
# 206000th data point has just been processed.
# 207000th data point has just been processed.
# 208000th data point has just been processed.
# 209000th data point has just been processed.
# 210000th data point has just been processed.
# 211000th data point has just been processed.
# 212000th data point has just been processed.
# 213000th data point has just been processed.
# 214000th data point has just been processed.
# 215000th data point has just been processed.
# 216000th data point has just been processed.
# 217000th data point has just been processed.
# 218000th data point has just been processed.
# 219000th data point has just been processed.
# 220000th data point has just been processed.
# 221000th data point has just been processed.
# 222000th data point has just been processed.
# 223000th data point has just been processed.
# 224000th data point has just been processed.
# 225000th data point has just been processed.
# 226000th data point has just been processed.
# 227000th data point has just been processed.
# 228000th data point has just been processed.
# 229000th data point has just been processed.
# 230000th data point has just been processed.
# 231000th data point has just been processed.
# 232000th data point has just been processed.
# 233000th data point has just been processed.
# 234000th data point has just been processed.
# 235000th data point has just been processed.
# 236000th data point has just been processed.
# 237000th data point has just been processed.
# 238000th data point has just been processed.
# 239000th data point has just been processed.
# 240000th data point has just been processed.
# 241000th data point has just been processed.
# 242000th data point has just been processed.
# 243000th data point has just been processed.
# 244000th data point has just been processed.
# 245000th data point has just been processed.
# 246000th data point has just been processed.
# 247000th data point has just been processed.
# 248000th data point has just been processed.
# 249000th data point has just been processed.
# 250000th data point has just been processed.
# 251000th data point has just been processed.
# 252000th data point has just been processed.
# 253000th data point has just been processed.
# 254000th data point has just been processed.
# 255000th data point has just been processed.
# 256000th data point has just been processed.
# 257000th data point has just been processed.
# 258000th data point has just been processed.
# 259000th data point has just been processed.
# 260000th data point has just been processed.
# 261000th data point has just been processed.
# 262000th data point has just been processed.
# 263000th data point has just been processed.
# 264000th data point has just been processed.
# 265000th data point has just been processed.
# 266000th data point has just been processed.
# 267000th data point has just been processed.
# 268000th data point has just been processed.
# 269000th data point has just been processed.
# 270000th data point has just been processed.
# 271000th data point has just been processed.
# 272000th data point has just been processed.
# 273000th data point has just been processed.
# 274000th data point has just been processed.
# 275000th data point has just been processed.
# 276000th data point has just been processed.
# 277000th data point has just been processed.
# 278000th data point has just been processed.
# 279000th data point has just been processed.
# 280000th data point has just been processed.
# 281000th data point has just been processed.
# 282000th data point has just been processed.
# 283000th data point has just been processed.
# 284000th data point has just been processed.
# 285000th data point has just been processed.
# 286000th data point has just been processed.
# 287000th data point has just been processed.
# 288000th data point has just been processed.
# 289000th data point has just been processed.
# 290000th data point has just been processed.
# 291000th data point has just been processed.
# 292000th data point has just been processed.
# 293000th data point has just been processed.
# 294000th data point has just been processed.
# 295000th data point has just been processed.
# 296000th data point has just been processed.
# 297000th data point has just been processed.
# 298000th data point has just been processed.
# 299000th data point has just been processed.
# 300000th data point has just been processed.
# 301000th data point has just been processed.
# 302000th data point has just been processed.
# 303000th data point has just been processed.
# 304000th data point has just been processed.
# 305000th data point has just been processed.
# 306000th data point has just been processed.
# 307000th data point has just been processed.
# 308000th data point has just been processed.
# 309000th data point has just been processed.
# 310000th data point has just been processed.
# 311000th data point has just been processed.
# 312000th data point has just been processed.
# 313000th data point has just been processed.
# 314000th data point has just been processed.
# 315000th data point has just been processed.
# 316000th data point has just been processed.
# 317000th data point has just been processed.
# 318000th data point has just been processed.
# 319000th data point has just been processed.
# 320000th data point has just been processed.
# 321000th data point has just been processed.
# 322000th data point has just been processed.
# 323000th data point has just been processed.
# 324000th data point has just been processed.
# 325000th data point has just been processed.
# 326000th data point has just been processed.
# 327000th data point has just been processed.
# 328000th data point has just been processed.
# 329000th data point has just been processed.
# 330000th data point has just been processed.
# 331000th data point has just been processed.
# 332000th data point has just been processed.
# 333000th data point has just been processed.
# 334000th data point has just been processed.
# 335000th data point has just been processed.
# 336000th data point has just been processed.
# 337000th data point has just been processed.
# 338000th data point has just been processed.
# 339000th data point has just been processed.
# 340000th data point has just been processed.
# 341000th data point has just been processed.
# 342000th data point has just been processed.
# 343000th data point has just been processed.
# 344000th data point has just been processed.
# 345000th data point has just been processed.
# 346000th data point has just been processed.
# 347000th data point has just been processed.
# 348000th data point has just been processed.
# 349000th data point has just been processed.
# 350000th data point has just been processed.
# 351000th data point has just been processed.
# 352000th data point has just been processed.
# 353000th data point has just been processed.
# 354000th data point has just been processed.
# 355000th data point has just been processed.
# 356000th data point has just been processed.
# 357000th data point has just been processed.
# 358000th data point has just been processed.
# 359000th data point has just been processed.
# 360000th data point has just been processed.
# 361000th data point has just been processed.
# 362000th data point has just been processed.
# 363000th data point has just been processed.
# 364000th data point has just been processed.
# 365000th data point has just been processed.
# 366000th data point has just been processed.
# 367000th data point has just been processed.
# 368000th data point has just been processed.
# 369000th data point has just been processed.
# 370000th data point has just been processed.
# 371000th data point has just been processed.
# 372000th data point has just been processed.
# 373000th data point has just been processed.
# 374000th data point has just been processed.
# 375000th data point has just been processed.
# 376000th data point has just been processed.
# 377000th data point has just been processed.
# 378000th data point has just been processed.
# 379000th data point has just been processed.
# 380000th data point has just been processed.
# 381000th data point has just been processed.
# 382000th data point has just been processed.
# 383000th data point has just been processed.
# 384000th data point has just been processed.
# 385000th data point has just been processed.
# 386000th data point has just been processed.
# 387000th data point has just been processed.
# 388000th data point has just been processed.
# 389000th data point has just been processed.
# 390000th data point has just been processed.
# 391000th data point has just been processed.
# 392000th data point has just been processed.
# 393000th data point has just been processed.
# 394000th data point has just been processed.
# 395000th data point has just been processed.
# 396000th data point has just been processed.
# 397000th data point has just been processed.
# 398000th data point has just been processed.
# 399000th data point has just been processed.
# 400000th data point has just been processed.
# 401000th data point has just been processed.
# 402000th data point has just been processed.
# 403000th data point has just been processed.
# 404000th data point has just been processed.
# 405000th data point has just been processed.
# 406000th data point has just been processed.
# 407000th data point has just been processed.
# 408000th data point has just been processed.
# 409000th data point has just been processed.
# 410000th data point has just been processed.
# 411000th data point has just been processed.
# 412000th data point has just been processed.
# 413000th data point has just been processed.
# 414000th data point has just been processed.
# 415000th data point has just been processed.
# 416000th data point has just been processed.
# 417000th data point has just been processed.
# 418000th data point has just been processed.
# 419000th data point has just been processed.
# 420000th data point has just been processed.
# 421000th data point has just been processed.
# 422000th data point has just been processed.
# 423000th data point has just been processed.
# 424000th data point has just been processed.
# 425000th data point has just been processed.
# 426000th data point has just been processed.
# 427000th data point has just been processed.
# 428000th data point has just been processed.
# 429000th data point has just been processed.
# 430000th data point has just been processed.
# 431000th data point has just been processed.
# 432000th data point has just been processed.
# 433000th data point has just been processed.
# 434000th data point has just been processed.
# 435000th data point has just been processed.
# 436000th data point has just been processed.
# 437000th data point has just been processed.
# 438000th data point has just been processed.
# 439000th data point has just been processed.
# 440000th data point has just been processed.
# 441000th data point has just been processed.
# 442000th data point has just been processed.
# 443000th data point has just been processed.
# 444000th data point has just been processed.
# 445000th data point has just been processed.
# 446000th data point has just been processed.
# 447000th data point has just been processed.
# 448000th data point has just been processed.
# 449000th data point has just been processed.
# 450000th data point has just been processed.
# 451000th data point has just been processed.
# 452000th data point has just been processed.
# 453000th data point has just been processed.
# 454000th data point has just been processed.
# 455000th data point has just been processed.
# 456000th data point has just been processed.
# 457000th data point has just been processed.
# 458000th data point has just been processed.
# 459000th data point has just been processed.
# 460000th data point has just been processed.
# 461000th data point has just been processed.
# 462000th data point has just been processed.
# 463000th data point has just been processed.
# 464000th data point has just been processed.
# 465000th data point has just been processed.
# 466000th data point has just been processed.
# 467000th data point has just been processed.
# 468000th data point has just been processed.
# 469000th data point has just been processed.
# 470000th data point has just been processed.
# 471000th data point has just been processed.
# 472000th data point has just been processed.
# 473000th data point has just been processed.
# 474000th data point has just been processed.
# 475000th data point has just been processed.
# 476000th data point has just been processed.
# 477000th data point has just been processed.
# 478000th data point has just been processed.
# 479000th data point has just been processed.
# 480000th data point has just been processed.
# 481000th data point has just been processed.
# 482000th data point has just been processed.
# 483000th data point has just been processed.
# 484000th data point has just been processed.
# 485000th data point has just been processed.
# 486000th data point has just been processed.
# 487000th data point has just been processed.
# 488000th data point has just been processed.
# 489000th data point has just been processed.
# 490000th data point has just been processed.
# 491000th data point has just been processed.
# 492000th data point has just been processed.
# 493000th data point has just been processed.
# 494000th data point has just been processed.
# 495000th data point has just been processed.
# 496000th data point has just been processed.
# 497000th data point has just been processed.
# 498000th data point has just been processed.
# 499000th data point has just been processed.
# 500000th data point has just been processed.
# 501000th data point has just been processed.
# 502000th data point has just been processed.
# 503000th data point has just been processed.
# 504000th data point has just been processed.
# 505000th data point has just been processed.
# 506000th data point has just been processed.
# 507000th data point has just been processed.
# 508000th data point has just been processed.
# 509000th data point has just been processed.
# 510000th data point has just been processed.
# 511000th data point has just been processed.
# 512000th data point has just been processed.
# 513000th data point has just been processed.
# 514000th data point has just been processed.
# 515000th data point has just been processed.
# 516000th data point has just been processed.
# 517000th data point has just been processed.
# 518000th data point has just been processed.
# 519000th data point has just been processed.
# 520000th data point has just been processed.
# 521000th data point has just been processed.
# 522000th data point has just been processed.
# 523000th data point has just been processed.
# 524000th data point has just been processed.
# 525000th data point has just been processed.
# 526000th data point has just been processed.
# 527000th data point has just been processed.
# 528000th data point has just been processed.
# 529000th data point has just been processed.
# 530000th data point has just been processed.
# 531000th data point has just been processed.
# 532000th data point has just been processed.
# 533000th data point has just been processed.
# 534000th data point has just been processed.
# 535000th data point has just been processed.
# 536000th data point has just been processed.
# 537000th data point has just been processed.
# 538000th data point has just been processed.
# 539000th data point has just been processed.
# 540000th data point has just been processed.
# 541000th data point has just been processed.
# 542000th data point has just been processed.
# 543000th data point has just been processed.
# 544000th data point has just been processed.
# 545000th data point has just been processed.
# 546000th data point has just been processed.
# 547000th data point has just been processed.
# 548000th data point has just been processed.
# 549000th data point has just been processed.
# 550000th data point has just been processed.
# 551000th data point has just been processed.
# 552000th data point has just been processed.
# 553000th data point has just been processed.
# 554000th data point has just been processed.
# 555000th data point has just been processed.
# 556000th data point has just been processed.
# 557000th data point has just been processed.
# 558000th data point has just been processed.
# 559000th data point has just been processed.
# 560000th data point has just been processed.
# 561000th data point has just been processed.
# 562000th data point has just been processed.
# 563000th data point has just been processed.
# 564000th data point has just been processed.
# 565000th data point has just been processed.
# 566000th data point has just been processed.
# 567000th data point has just been processed.
# 568000th data point has just been processed.
# 569000th data point has just been processed.
# 570000th data point has just been processed.
# 571000th data point has just been processed.
# 572000th data point has just been processed.
# 573000th data point has just been processed.
# 574000th data point has just been processed.
# 575000th data point has just been processed.
# 576000th data point has just been processed.
# 577000th data point has just been processed.
# 578000th data point has just been processed.
# 579000th data point has just been processed.
# 580000th data point has just been processed.
# 581000th data point has just been processed.
# 582000th data point has just been processed.
# 583000th data point has just been processed.
# 584000th data point has just been processed.
# 585000th data point has just been processed.
# 586000th data point has just been processed.
# 587000th data point has just been processed.
# 588000th data point has just been processed.
# 589000th data point has just been processed.
# 590000th data point has just been processed.
# 591000th data point has just been processed.
# 592000th data point has just been processed.
# 593000th data point has just been processed.
# 594000th data point has just been processed.
# 595000th data point has just been processed.
# 596000th data point has just been processed.
# 597000th data point has just been processed.
# 598000th data point has just been processed.
# 599000th data point has just been processed.
# 600000th data point has just been processed.
# 601000th data point has just been processed.
# 602000th data point has just been processed.
# 603000th data point has just been processed.
# 604000th data point has just been processed.
# 605000th data point has just been processed.
# 606000th data point has just been processed.
# 607000th data point has just been processed.
# 608000th data point has just been processed.
# 609000th data point has just been processed.
# 610000th data point has just been processed.
# 611000th data point has just been processed.
# 612000th data point has just been processed.
# 613000th data point has just been processed.
# 614000th data point has just been processed.
# 615000th data point has just been processed.
# 616000th data point has just been processed.
# 617000th data point has just been processed.
# 618000th data point has just been processed.
# 619000th data point has just been processed.
# 620000th data point has just been processed.
# 621000th data point has just been processed.
# 622000th data point has just been processed.
# 623000th data point has just been processed.
# 624000th data point has just been processed.
# 625000th data point has just been processed.
# 626000th data point has just been processed.
# 627000th data point has just been processed.
# 628000th data point has just been processed.
# 629000th data point has just been processed.
# 630000th data point has just been processed.
# 631000th data point has just been processed.
# 632000th data point has just been processed.
# 633000th data point has just been processed.
# 634000th data point has just been processed.
# 635000th data point has just been processed.
# 636000th data point has just been processed.
# 637000th data point has just been processed.
# 638000th data point has just been processed.
# 639000th data point has just been processed.
# 640000th data point has just been processed.
# 641000th data point has just been processed.
# 642000th data point has just been processed.
# 643000th data point has just been processed.
# 644000th data point has just been processed.
# 645000th data point has just been processed.
# 646000th data point has just been processed.
# 647000th data point has just been processed.
# 648000th data point has just been processed.
# 649000th data point has just been processed.
# 650000th data point has just been processed.
# 651000th data point has just been processed.
# 652000th data point has just been processed.
# 653000th data point has just been processed.
# 654000th data point has just been processed.
# 655000th data point has just been processed.
# 656000th data point has just been processed.
# 657000th data point has just been processed.
# 658000th data point has just been processed.
# 659000th data point has just been processed.
# 660000th data point has just been processed.
# 661000th data point has just been processed.
# 662000th data point has just been processed.
# 663000th data point has just been processed.
# 664000th data point has just been processed.
# 665000th data point has just been processed.
# 666000th data point has just been processed.
# 667000th data point has just been processed.
# 668000th data point has just been processed.
# 669000th data point has just been processed.
# 670000th data point has just been processed.
# 671000th data point has just been processed.
# 672000th data point has just been processed.
# 673000th data point has just been processed.
# 674000th data point has just been processed.
# 675000th data point has just been processed.
# 676000th data point has just been processed.
# 677000th data point has just been processed.
# 678000th data point has just been processed.
# 679000th data point has just been processed.
# 680000th data point has just been processed.
# 681000th data point has just been processed.
# 682000th data point has just been processed.
# 683000th data point has just been processed.
# 684000th data point has just been processed.
# 685000th data point has just been processed.
# 686000th data point has just been processed.
# 687000th data point has just been processed.
# 688000th data point has just been processed.
# 689000th data point has just been processed.
# 690000th data point has just been processed.
# 691000th data point has just been processed.
# 692000th data point has just been processed.
# 693000th data point has just been processed.
# 694000th data point has just been processed.
# 695000th data point has just been processed.
# 696000th data point has just been processed.
# 697000th data point has just been processed.
# 698000th data point has just been processed.
# 699000th data point has just been processed.
# 700000th data point has just been processed.
# 701000th data point has just been processed.
# 702000th data point has just been processed.
# 703000th data point has just been processed.
# 704000th data point has just been processed.
# 705000th data point has just been processed.
# 706000th data point has just been processed.
# 707000th data point has just been processed.
# 708000th data point has just been processed.
# 709000th data point has just been processed.
# 710000th data point has just been processed.
# 711000th data point has just been processed.
# 712000th data point has just been processed.
# 713000th data point has just been processed.
# 714000th data point has just been processed.
# 715000th data point has just been processed.
# 716000th data point has just been processed.
# 717000th data point has just been processed.
# 718000th data point has just been processed.
# 719000th data point has just been processed.
# 720000th data point has just been processed.
# 721000th data point has just been processed.
# 722000th data point has just been processed.
# 723000th data point has just been processed.
# 724000th data point has just been processed.
# 725000th data point has just been processed.
# 726000th data point has just been processed.
# 727000th data point has just been processed.
# 728000th data point has just been processed.
# 729000th data point has just been processed.
# 730000th data point has just been processed.
# 731000th data point has just been processed.
# 732000th data point has just been processed.
# 733000th data point has just been processed.
# 734000th data point has just been processed.
# 735000th data point has just been processed.
# 736000th data point has just been processed.
# 737000th data point has just been processed.
# 738000th data point has just been processed.
# 739000th data point has just been processed.
# 740000th data point has just been processed.
# 741000th data point has just been processed.
# 742000th data point has just been processed.
# 743000th data point has just been processed.
# 744000th data point has just been processed.
# 745000th data point has just been processed.
# 746000th data point has just been processed.
# 747000th data point has just been processed.
# 748000th data point has just been processed.
# 749000th data point has just been processed.
# 750000th data point has just been processed.
# 751000th data point has just been processed.
# 752000th data point has just been processed.
# 753000th data point has just been processed.
# 754000th data point has just been processed.
# 755000th data point has just been processed.
# 756000th data point has just been processed.
# 757000th data point has just been processed.
# 758000th data point has just been processed.
# 759000th data point has just been processed.
# 760000th data point has just been processed.
# 761000th data point has just been processed.
# 762000th data point has just been processed.
# 763000th data point has just been processed.
# 764000th data point has just been processed.
# 765000th data point has just been processed.
# 766000th data point has just been processed.
# 767000th data point has just been processed.
# 768000th data point has just been processed.
# 769000th data point has just been processed.
# 770000th data point has just been processed.
# 771000th data point has just been processed.
# 772000th data point has just been processed.
# 773000th data point has just been processed.
# 774000th data point has just been processed.
# 775000th data point has just been processed.
# 776000th data point has just been processed.
# 777000th data point has just been processed.
# 778000th data point has just been processed.
# 779000th data point has just been processed.
# 780000th data point has just been processed.
# 781000th data point has just been processed.
# 782000th data point has just been processed.
# 783000th data point has just been processed.
# 784000th data point has just been processed.
# 785000th data point has just been processed.
# 786000th data point has just been processed.
# 787000th data point has just been processed.
# 788000th data point has just been processed.
# 789000th data point has just been processed.
# 790000th data point has just been processed.
# 791000th data point has just been processed.
# 792000th data point has just been processed.
# 793000th data point has just been processed.
# 794000th data point has just been processed.
# 795000th data point has just been processed.
# 796000th data point has just been processed.
# 797000th data point has just been processed.
# 798000th data point has just been processed.
# 799000th data point has just been processed.
# 800000th data point has just been processed.
# 801000th data point has just been processed.
# 802000th data point has just been processed.
# 803000th data point has just been processed.
# 804000th data point has just been processed.
# 805000th data point has just been processed.
# 806000th data point has just been processed.
# 807000th data point has just been processed.
# 808000th data point has just been processed.
# 809000th data point has just been processed.
# 810000th data point has just been processed.
# 811000th data point has just been processed.
# 812000th data point has just been processed.
# 813000th data point has just been processed.
# 814000th data point has just been processed.
# 815000th data point has just been processed.
# 816000th data point has just been processed.
# 817000th data point has just been processed.
# 818000th data point has just been processed.
# 819000th data point has just been processed.
# 820000th data point has just been processed.
# 821000th data point has just been processed.
# 822000th data point has just been processed.
# 823000th data point has just been processed.
# 824000th data point has just been processed.
# 825000th data point has just been processed.
# 826000th data point has just been processed.
# 827000th data point has just been processed.
# 828000th data point has just been processed.
# 829000th data point has just been processed.
# 830000th data point has just been processed.
# 831000th data point has just been processed.
# 832000th data point has just been processed.
# 833000th data point has just been processed.
# 834000th data point has just been processed.
# 835000th data point has just been processed.
# 836000th data point has just been processed.
# 837000th data point has just been processed.
# 838000th data point has just been processed.
# 839000th data point has just been processed.
# 840000th data point has just been processed.
# 841000th data point has just been processed.
# 842000th data point has just been processed.
# 843000th data point has just been processed.
# 844000th data point has just been processed.
# 845000th data point has just been processed.
# 846000th data point has just been processed.
# 847000th data point has just been processed.
# 848000th data point has just been processed.
# 849000th data point has just been processed.
# 850000th data point has just been processed.
# 851000th data point has just been processed.
# 852000th data point has just been processed.
# 853000th data point has just been processed.
# 854000th data point has just been processed.
# 855000th data point has just been processed.
# 856000th data point has just been processed.
# 857000th data point has just been processed.
# 858000th data point has just been processed.
# 859000th data point has just been processed.
# 860000th data point has just been processed.
# 861000th data point has just been processed.
# 862000th data point has just been processed.
# 863000th data point has just been processed.
# 864000th data point has just been processed.
# 865000th data point has just been processed.
# 866000th data point has just been processed.
# 867000th data point has just been processed.
# 868000th data point has just been processed.
# 869000th data point has just been processed.
# 870000th data point has just been processed.
# 871000th data point has just been processed.
# 872000th data point has just been processed.
# 873000th data point has just been processed.
# 874000th data point has just been processed.
# 875000th data point has just been processed.
# 876000th data point has just been processed.
# 877000th data point has just been processed.
# 878000th data point has just been processed.
# 879000th data point has just been processed.
# 880000th data point has just been processed.
# 881000th data point has just been processed.
# 882000th data point has just been processed.
# 883000th data point has just been processed.
# 884000th data point has just been processed.
# 885000th data point has just been processed.
# 886000th data point has just been processed.
# 887000th data point has just been processed.
# 888000th data point has just been processed.
# 889000th data point has just been processed.
# 890000th data point has just been processed.
# 891000th data point has just been processed.
# 892000th data point has just been processed.
# 893000th data point has just been processed.
# 894000th data point has just been processed.
# 895000th data point has just been processed.
# 896000th data point has just been processed.
# 897000th data point has just been processed.
# 898000th data point has just been processed.
# 899000th data point has just been processed.
# 900000th data point has just been processed.
# 901000th data point has just been processed.
# 902000th data point has just been processed.
# 903000th data point has just been processed.
# 904000th data point has just been processed.
# 905000th data point has just been processed.
# 906000th data point has just been processed.
# 907000th data point has just been processed.
# 908000th data point has just been processed.
# 909000th data point has just been processed.
# 910000th data point has just been processed.
# 911000th data point has just been processed.
# 912000th data point has just been processed.
# 913000th data point has just been processed.
# 914000th data point has just been processed.
# 915000th data point has just been processed.
# 916000th data point has just been processed.
# 917000th data point has just been processed.
# 918000th data point has just been processed.
# 919000th data point has just been processed.
# 920000th data point has just been processed.
# 921000th data point has just been processed.
# 922000th data point has just been processed.
# 923000th data point has just been processed.
# 924000th data point has just been processed.
# 925000th data point has just been processed.
# 926000th data point has just been processed.
# 927000th data point has just been processed.
# 928000th data point has just been processed.
# 929000th data point has just been processed.
# 930000th data point has just been processed.
# 931000th data point has just been processed.
# 932000th data point has just been processed.
# 933000th data point has just been processed.
# 934000th data point has just been processed.
# 935000th data point has just been processed.
# 936000th data point has just been processed.
# 937000th data point has just been processed.
# 938000th data point has just been processed.
# 939000th data point has just been processed.
# 940000th data point has just been processed.
# 941000th data point has just been processed.
# 942000th data point has just been processed.
# 943000th data point has just been processed.
# 944000th data point has just been processed.
# 945000th data point has just been processed.
# 946000th data point has just been processed.
# 947000th data point has just been processed.
# 948000th data point has just been processed.
# 949000th data point has just been processed.
# 950000th data point has just been processed.
# 951000th data point has just been processed.
# 952000th data point has just been processed.
# 953000th data point has just been processed.
# 954000th data point has just been processed.
# 955000th data point has just been processed.
# 956000th data point has just been processed.
# 957000th data point has just been processed.
# 958000th data point has just been processed.
# 959000th data point has just been processed.
# 960000th data point has just been processed.
# 961000th data point has just been processed.
# 962000th data point has just been processed.
# 963000th data point has just been processed.
# 964000th data point has just been processed.
# 965000th data point has just been processed.
# 966000th data point has just been processed.
# 967000th data point has just been processed.
# 968000th data point has just been processed.
# 969000th data point has just been processed.
# 970000th data point has just been processed.
# 971000th data point has just been processed.
# 972000th data point has just been processed.
# 973000th data point has just been processed.
# 974000th data point has just been processed.
# 975000th data point has just been processed.
# 976000th data point has just been processed.
# 977000th data point has just been processed.
# 978000th data point has just been processed.
# 979000th data point has just been processed.
# 980000th data point has just been processed.
# 981000th data point has just been processed.
# 982000th data point has just been processed.
# 983000th data point has just been processed.
# 984000th data point has just been processed.
# 985000th data point has just been processed.
# 986000th data point has just been processed.
# 987000th data point has just been processed.
# 988000th data point has just been processed.
# 989000th data point has just been processed.
# 990000th data point has just been processed.
# 991000th data point has just been processed.
# 992000th data point has just been processed.
# 993000th data point has just been processed.
# 994000th data point has just been processed.
# 995000th data point has just been processed.
# 996000th data point has just been processed.
# 997000th data point has just been processed.
# 998000th data point has just been processed.
# 999000th data point has just been processed.
# 1000000th data point has just been processed.
# 1001000th data point has just been processed.
# 1002000th data point has just been processed.
# 1003000th data point has just been processed.
# 1004000th data point has just been processed.
# 1005000th data point has just been processed.
# 1006000th data point has just been processed.
# 1007000th data point has just been processed.
# 1008000th data point has just been processed.
# 1009000th data point has just been processed.
# 1010000th data point has just been processed.
# 1011000th data point has just been processed.
# 1012000th data point has just been processed.
# 1013000th data point has just been processed.
# 1014000th data point has just been processed.
# 1015000th data point has just been processed.
# 1016000th data point has just been processed.
# 1017000th data point has just been processed.
# 1018000th data point has just been processed.
# 1019000th data point has just been processed.
# 1020000th data point has just been processed.
# 1021000th data point has just been processed.
# 1022000th data point has just been processed.
# 1023000th data point has just been processed.
# 1024000th data point has just been processed.
# 1025000th data point has just been processed.
# 1026000th data point has just been processed.
# 1027000th data point has just been processed.
# 1028000th data point has just been processed.
# 1029000th data point has just been processed.
# 1030000th data point has just been processed.
# 1031000th data point has just been processed.
# 1032000th data point has just been processed.
# 1033000th data point has just been processed.
# 1034000th data point has just been processed.
# 1035000th data point has just been processed.
# 1036000th data point has just been processed.
# 1037000th data point has just been processed.
# 1038000th data point has just been processed.
# 1039000th data point has just been processed.
# 1040000th data point has just been processed.
# 1041000th data point has just been processed.
# 1042000th data point has just been processed.
# 1043000th data point has just been processed.
# 1044000th data point has just been processed.
# 1045000th data point has just been processed.
# 1046000th data point has just been processed.
# 1047000th data point has just been processed.
# 1048000th data point has just been processed.
# 1049000th data point has just been processed.
# 1050000th data point has just been processed.
# 1051000th data point has just been processed.
# 1052000th data point has just been processed.
# 1053000th data point has just been processed.
# 1054000th data point has just been processed.
# 1055000th data point has just been processed.
# 1056000th data point has just been processed.
# 1057000th data point has just been processed.
# 1058000th data point has just been processed.
# 1059000th data point has just been processed.
# 1060000th data point has just been processed.
# 1061000th data point has just been processed.
# 1062000th data point has just been processed.
# 1063000th data point has just been processed.
# 1064000th data point has just been processed.
# 1065000th data point has just been processed.
# 1066000th data point has just been processed.
# ...
# 2462000th data point has just been processed.
# 2463000th data point has just been processed.
# 2464000th data point has just been processed.
# 2465000th data point has just been processed.
# 2466000th data point has just been processed.
# 2467000th data point has just been processed.
# 2468000th data point has just been processed.
# 2469000th data point has just been processed.
# 2470000th data point has just been processed.
# 2471000th data point has just been processed.
# 2472000th data point has just been processed.
# 2473000th data point has just been processed.
# 2474000th data point has just been processed.
# 2475000th data point has just been processed.
# 2476000th data point has just been processed.
# 2477000th data point has just been processed.
# 2478000th data point has just been processed.
# 2479000th data point has just been processed.
# 2480000th data point has just been processed.
# 2481000th data point has just been processed.
# 2482000th data point has just been processed.
# 2483000th data point has just been processed.
# 2484000th data point has just been processed.
# 2485000th data point has just been processed.
# 2486000th data point has just been processed.
# 2487000th data point has just been processed.
# 2488000th data point has just been processed.
# 2489000th data point has just been processed.
# 2490000th data point has just been processed.
# 2491000th data point has just been processed.
# 2492000th data point has just been processed.
# 2493000th data point has just been processed.
# 2494000th data point has just been processed.
# 2495000th data point has just been processed.
# 2496000th data point has just been processed.
# 2497000th data point has just been processed.
# 2498000th data point has just been processed.
# 2499000th data point has just been processed.
# 2500000th data point has just been processed.
# 2501000th data point has just been processed.
# 2502000th data point has just been processed.
# 2503000th data point has just been processed.
# 2504000th data point has just been processed.
# 2505000th data point has just been processed.
# 2506000th data point has just been processed.
# 2507000th data point has just been processed.
# 2508000th data point has just been processed.
# 2509000th data point has just been processed.
# 2510000th data point has just been processed.
# 2511000th data point has just been processed.
# 2512000th data point has just been processed.
# 2513000th data point has just been processed.
# 2514000th data point has just been processed.
# 2515000th data point has just been processed.
# 2516000th data point has just been processed.
# 2517000th data point has just been processed.
# 2518000th data point has just been processed.
# 2519000th data point has just been processed.
# 2520000th data point has just been processed.
# 2521000th data point has just been processed.
# 2522000th data point has just been processed.
# 2523000th data point has just been processed.
# 2524000th data point has just been processed.
# 2525000th data point has just been processed.
# 2526000th data point has just been processed.
# 2527000th data point has just been processed.
# 2528000th data point has just been processed.
# 2529000th data point has just been processed.
# 2530000th data point has just been processed.
# 2531000th data point has just been processed.
# 2532000th data point has just been processed.
# 2533000th data point has just been processed.
# 2534000th data point has just been processed.
# 2535000th data point has just been processed.
# 2536000th data point has just been processed.
# 2537000th data point has just been processed.
# 2538000th data point has just been processed.
# 2539000th data point has just been processed.
# 2540000th data point has just been processed.
# 2541000th data point has just been processed.
# 2542000th data point has just been processed.
# 2543000th data point has just been processed.
# 2544000th data point has just been processed.
# 2545000th data point has just been processed.
# 2546000th data point has just been processed.
# 2547000th data point has just been processed.
# 2548000th data point has just been processed.
# 2549000th data point has just been processed.
# 2550000th data point has just been processed.
# 2551000th data point has just been processed.
# 2552000th data point has just been processed.
# 2553000th data point has just been processed.
# 2554000th data point has just been processed.
# 2555000th data point has just been processed.
# 2556000th data point has just been processed.
# 2557000th data point has just been processed.
# 2558000th data point has just been processed.
# 2559000th data point has just been processed.
# 2560000th data point has just been processed.
# 2561000th data point has just been processed.
# 2562000th data point has just been processed.
# 2563000th data point has just been processed.
# 2564000th data point has just been processed.
# 2565000th data point has just been processed.
# 2566000th data point has just been processed.
# 2567000th data point has just been processed.
# 2568000th data point has just been processed.
# 2569000th data point has just been processed.
# 2570000th data point has just been processed.
# 2571000th data point has just been processed.
# 2572000th data point has just been processed.
# 2573000th data point has just been processed.
# 2574000th data point has just been processed.
# 2575000th data point has just been processed.
# 2576000th data point has just been processed.
# 2577000th data point has just been processed.
# 2578000th data point has just been processed.
# 2579000th data point has just been processed.
# 2580000th data point has just been processed.
# 2581000th data point has just been processed.
# 2582000th data point has just been processed.
# 2583000th data point has just been processed.
# 2584000th data point has just been processed.
# 2585000th data point has just been processed.
# 2586000th data point has just been processed.
# 2587000th data point has just been processed.
# 2588000th data point has just been processed.
# 2589000th data point has just been processed.
# 2590000th data point has just been processed.
# 2591000th data point has just been processed.
# 2592000th data point has just been processed.
# 2593000th data point has just been processed.
# 2594000th data point has just been processed.
# 2595000th data point has just been processed.
# 2596000th data point has just been processed.
# 2597000th data point has just been processed.
# 2598000th data point has just been processed.
# 2599000th data point has just been processed.
# 2600000th data point has just been processed.
# 2601000th data point has just been processed.
# 2602000th data point has just been processed.
# 2603000th data point has just been processed.
# 2604000th data point has just been processed.
# 2605000th data point has just been processed.
# 2606000th data point has just been processed.
# 2607000th data point has just been processed.
# 2608000th data point has just been processed.
# 2609000th data point has just been processed.
# 2610000th data point has just been processed.
# 2611000th data point has just been processed.
# 2612000th data point has just been processed.
# 2613000th data point has just been processed.
# 2614000th data point has just been processed.
# 2615000th data point has just been processed.
# 2616000th data point has just been processed.
# 2617000th data point has just been processed.
# 2618000th data point has just been processed.
# 2619000th data point has just been processed.
# 2620000th data point has just been processed.
# 2621000th data point has just been processed.
# 2622000th data point has just been processed.
# 2623000th data point has just been processed.
# 2624000th data point has just been processed.
# 2625000th data point has just been processed.
# 2626000th data point has just been processed.
# 2627000th data point has just been processed.
# 2628000th data point has just been processed.
# 2629000th data point has just been processed.
# 2630000th data point has just been processed.
# 2631000th data point has just been processed.
# 2632000th data point has just been processed.
# 2633000th data point has just been processed.
# 2634000th data point has just been processed.
# 2635000th data point has just been processed.
# 2636000th data point has just been processed.
# 2637000th data point has just been processed.
# 2638000th data point has just been processed.
# 2639000th data point has just been processed.
# 2640000th data point has just been processed.
# 2641000th data point has just been processed.
# 2642000th data point has just been processed.
# 2643000th data point has just been processed.
# 2644000th data point has just been processed.
# 2645000th data point has just been processed.
# 2646000th data point has just been processed.
# 2647000th data point has just been processed.
# 2648000th data point has just been processed.
# 2649000th data point has just been processed.
# 2650000th data point has just been processed.
# 2651000th data point has just been processed.
# 2652000th data point has just been processed.
# 2653000th data point has just been processed.
# 2654000th data point has just been processed.
# 2655000th data point has just been processed.
# 2656000th data point has just been processed.
# 2657000th data point has just been processed.
# 2658000th data point has just been processed.
# 2659000th data point has just been processed.
# 2660000th data point has just been processed.
# 2661000th data point has just been processed.
# 2662000th data point has just been processed.
# 2663000th data point has just been processed.
# 2664000th data point has just been processed.
# 2665000th data point has just been processed.
# 2666000th data point has just been processed.
# 2667000th data point has just been processed.
# 2668000th data point has just been processed.
# 2669000th data point has just been processed.
# 2670000th data point has just been processed.
# 2671000th data point has just been processed.
# 2672000th data point has just been processed.
# 2673000th data point has just been processed.
# 2674000th data point has just been processed.
# 2675000th data point has just been processed.
# 2676000th data point has just been processed.
# 2677000th data point has just been processed.
# 2678000th data point has just been processed.
# 2679000th data point has just been processed.
# 2680000th data point has just been processed.
# 2681000th data point has just been processed.
# 2682000th data point has just been processed.
# 2683000th data point has just been processed.
# 2684000th data point has just been processed.
# 2685000th data point has just been processed.
# 2686000th data point has just been processed.
# 2687000th data point has just been processed.
# 2688000th data point has just been processed.
# 2689000th data point has just been processed.
# 2690000th data point has just been processed.
# 2691000th data point has just been processed.
# 2692000th data point has just been processed.
# 2693000th data point has just been processed.
# 2694000th data point has just been processed.
# 2695000th data point has just been processed.
# 2696000th data point has just been processed.
# 2697000th data point has just been processed.
# 2698000th data point has just been processed.
# 2699000th data point has just been processed.
# 2700000th data point has just been processed.
# 2701000th data point has just been processed.
# 2702000th data point has just been processed.
# 2703000th data point has just been processed.
# 2704000th data point has just been processed.
# 2705000th data point has just been processed.
# 2706000th data point has just been processed.
# 2707000th data point has just been processed.
# 2708000th data point has just been processed.
# 2709000th data point has just been processed.
# 2710000th data point has just been processed.
# 2711000th data point has just been processed.
# 2712000th data point has just been processed.
# 2713000th data point has just been processed.
# 2714000th data point has just been processed.
# 2715000th data point has just been processed.
# 2716000th data point has just been processed.
# 2717000th data point has just been processed.
# 2718000th data point has just been processed.
# 2719000th data point has just been processed.
# 2720000th data point has just been processed.
# 2721000th data point has just been processed.
# 2722000th data point has just been processed.
# 2723000th data point has just been processed.
# 2724000th data point has just been processed.
# 2725000th data point has just been processed.
# 2726000th data point has just been processed.
# 2727000th data point has just been processed.
# 2728000th data point has just been processed.
# 2729000th data point has just been processed.
# 2730000th data point has just been processed.
# 2731000th data point has just been processed.
# 2732000th data point has just been processed.
# 2733000th data point has just been processed.
# 2734000th data point has just been processed.
# 2735000th data point has just been processed.
# 2736000th data point has just been processed.
# 2737000th data point has just been processed.
# 2738000th data point has just been processed.
# 2739000th data point has just been processed.
# 2740000th data point has just been processed.
# 2741000th data point has just been processed.
# 2742000th data point has just been processed.
# 2743000th data point has just been processed.
# 2744000th data point has just been processed.
# 2745000th data point has just been processed.
# 2746000th data point has just been processed.
# 2747000th data point has just been processed.
# 2748000th data point has just been processed.
# 2749000th data point has just been processed.
# 2750000th data point has just been processed.
# 2751000th data point has just been processed.
# 2752000th data point has just been processed.
# 2753000th data point has just been processed.
# 2754000th data point has just been processed.
# 2755000th data point has just been processed.
# 2756000th data point has just been processed.
# 2757000th data point has just been processed.
# 2758000th data point has just been processed.
# 2759000th data point has just been processed.
# 2760000th data point has just been processed.
# 2761000th data point has just been processed.
# 2762000th data point has just been processed.
# 2763000th data point has just been processed.
# 2764000th data point has just been processed.
# 2765000th data point has just been processed.
# 2766000th data point has just been processed.
# 2767000th data point has just been processed.
# 2768000th data point has just been processed.
# 2769000th data point has just been processed.
# 2770000th data point has just been processed.
# 2771000th data point has just been processed.
# 2772000th data point has just been processed.
# 2773000th data point has just been processed.
# 2774000th data point has just been processed.
# 2775000th data point has just been processed.
# 2776000th data point has just been processed.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26148/2521434753.py in <module>
#      15 writer = pd.ExcelWriter('nwm.20220818_analysis_assim_nwm.t00z.analysis_assim.channel_rt.tm00.conus.RegressionData.xlsx',\
#      16                         engine='xlsxwriter')
# ---> 17 df.to_excel(writer, sheet_name='Data', index=False)
#      18 writer.save()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     821         num_rows, num_cols = self.df.shape
#     822         if num_rows > self.max_rows or num_cols > self.max_cols:
# --> 823             raise ValueError(
#     824                 f"This sheet is too large! Your sheet size is: {num_rows}, {num_cols} "
#     825                 f"Max sheet size is: {self.max_rows}, {self.max_cols}"
#
# ValueError: This sheet is too large! Your sheet size is: 2776738, 6 Max sheet size is: 1048576, 16384

# %%
#Partition the data sets with 2.7 million records into three different excel files as maximum row limit in excel is around a million data points
len1=int(len(dataSet)/3)
len2=int(len(dataSet)*2/3)

dataset1of3=dataSet[:len1]
dataset2of3=dataSet[len1:len2]
dataset3of3=dataSet[len2:]

df1 = pd.DataFrame(dataset1of3)
df2 = pd.DataFrame(dataset2of3)
df3 = pd.DataFrame(dataset3of3)

writer1 = pd.ExcelWriter('1of3nwm.20220818_analysis_assim_nwm.t00z.analysis_assim.channel_rt.tm00.conus.RegressionData.xlsx',\
                        engine='xlsxwriter')
writer2 = pd.ExcelWriter('2of3nwm.20220818_analysis_assim_nwm.t00z.analysis_assim.channel_rt.tm00.conus.RegressionData.xlsx',\
                        engine='xlsxwriter')
writer3 = pd.ExcelWriter('3of3nwm.20220818_analysis_assim_nwm.t00z.analysis_assim.channel_rt.tm00.conus.RegressionData.xlsx',\
                        engine='xlsxwriter')

df1.to_excel(writer1, sheet_name='Data', index=False)
df2.to_excel(writer2, sheet_name='Data', index=False)
df3.to_excel(writer3, sheet_name='Data', index=False)

writer1.save()
writer2.save()
writer3.save()

# %%
ds1
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     TITLE: OUTPUT FROM NWM v2.2
#     featureType: timeSeries
#     proj4: +proj=lcc +units=m +a=6370000.0 +b=6370000.0 +lat_1=30.0 +lat_2=60.0 +lat_0=40.0 +lon_0=-97.0 +x_0=0 +y_0=0 +k_0=1.0 +nadgrids=@
#     model_initialization_time: 2022-08-17_21:00:00
#     station_dimension: feature_id
#     model_output_valid_time: 2022-08-18_00:00:00
#     model_total_valid_times: 3
#     stream_order_output: 1
#     cdm_datatype: Station
#     Conventions: CF-1.6
#     code_version: v5.2.0-beta2
#     NWM_version_number: v2.2
#     model_output_type: channel_rt
#     model_configuration: analysis_and_assimilation
#     dev_OVRTSWCRT: 1
#     dev_NOAH_TIMESTEP: 3600
#     dev_channel_only: 0
#     dev_channelBucket_only: 0
#     dev: dev_ prefix indicates development/internal meta data
#     dimensions(sizes): feature_id(2776738), time(1), reference_time(1)
#     variables(dimensions): int32 time(time), int32 reference_time(reference_time), |S1 crs(), int32 feature_id(feature_id), int32 streamflow(feature_id), int32 nudge(feature_id), int32 velocity(feature_id), int32 qSfcLatRunoff(feature_id), int32 qBucket(feature_id), int32 qBtmVertRunoff(feature_id)
#     groups:
